# %%
age=25
if age>=18:
    print("Eligibal to vote")
else:
    print("Not eligibal to vote")
# Out:
# Eligibal to vote

# %%
age=12
if age>=18:
    print("Eligibal to vote")
else:
    print("Not eligibal to vote")
# Out:
# Not eligibal to vote

# %%
marks=85
if marks>=90:
    print("Grade A")
elif marks>=75:
    print("Grade B")
elif marks>=60:
    print("Grade C")
# Out:
# Grade B

# %%
marks=15
if marks>=90:
    print("Grade A")
elif marks>=75:
    print("Grade B")
elif marks>=60:
    print("Grade C")
elif marks<=35:
    print("Fail")
# Out:
# Fail

# %%
num=34
if(num%2==0):
    print("Num is even")
else:
    print("num is odd")
# Out:
# Num is even

# %%
num=int(input("Enter a number"))

if(num%2==0):
    print("Num is even")
elif(num%2!=0):
    print("num is odd")
# Out:
# Enter a number 35
# num is odd

# %%
a=int(input("Enter a"))
b=int(input("Enter b"))
c=int(input("Enter c"))
if(a>=b and a>=c):
    print("a is a greater ")
elif(b>=a and b>=c):
    print("b is a greater ")
elif(c>=a and c>=b):
    print("c is a greater ")
# Out:
# Enter a 2
# Enter b 3
# Enter c 4
# c is a greater

# %%
age=25
citizen=True
if age>=18:
    if citizen:
        print("Eligibal to vote")
    else:
        print("Not Eligibal")
# Out:
# Eligibal to vote

# %%
age=35
if age>=18 and age<=65:
    print("Working age")
# Out:
# Working age

# %%
marks=35
if marks>=18 and marks<=65:
    print("Eligibal for Gracing Marks")
# Out:
# Eligibal for Gracing Marks

# %%
is_holiday=False
if not is_holiday:
    print("Go to office")
else:
     print(" do not Go to office")
# Out:
# Go to office

# %%
age = 25
status = "adult" if age >= 18 else"minor"
print(status)
# Out:
# adult

# %%
age = 25
status = "adult" if age >= 18 else "minor"
print(status)
# Out:
# adult

# %%
year=int(input("Enter a year"))

if(year%400==0):
    print("year is Leap")
elif(year%400!=0):
    print("year is not a Leap year")
# Out:
# Enter a year 2025
# year is not a Leap year

# %%
salary=6000
experince=4
if salary >= 5000 and experince >=3:
    print("Eligibal for promotion ")
else:
    print("not eligibal")
# Out:
# Eligibal for promotion
