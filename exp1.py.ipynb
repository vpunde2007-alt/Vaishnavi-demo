# %%
print("Hello World")
# Out:
# Hello World

# %%
print(20+10)
# Out:
# 30

# %%
a=10
b=3.2
c="dkte"
print(a)

print(type(a))
print(type(b))
print(type(c))
# Out:
# 10
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
print("20+10")
# Out:
# 20+10

# %%
name='vaishnavi'
print("my name:",name)
# Out:
# my name: vaishnavi

# %%
print(12+23)
print(34-12)
print(98/2)
print(56*4)
# Out:
# 35
# 22
# 49.0
# 224
