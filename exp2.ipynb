# %%
print(10+20)
print(23-12)
print(34*5)
print(56/7)
print(34%2)
# Out:
# 30
# 11
# 170
# 8.0
# 0

# %%
age=25
print(age>18 or age<20)
# Out:
# True

# %%
age =20
print(not(age>18))
# Out:
# False

# %%
a=10
a+=5
print(a)
# Out:
# 15

# %%
a=10
a-=5
print(a)
# Out:
# 5

# %%
a=10
a*=4
print(a)
# Out:
# 40

# %%
a=10
a/=2
print(a)
# Out:
# 5.0

# %%
a=25
print(a)
print(type(a))
# Out:
# 25
# <class 'int'>

# %%
a=10.3
print(a)
print(type(a))
# Out:
# 10.3
# <class 'float'>

# %%
is_student=True

print(type(is_student))
# Out:
# <class 'bool'>

# %%
is_student=False
print(type(is_student))
# Out:
# <class 'bool'>

# %%
a="dkte"
print(a)
print(type(a))
# Out:
# dkte
# <class 'str'>

# %%
input("Enter Name")
# Out:
# Enter NameVaishnavi
# 'Vaishnavi'

# %%
a=input("Enter name")
print("Hello",a)

# %%
name=input("Enter name")
age=input("Enter age")
print("my name is",name,"my age is",age)
# Out:
# Enter name vaishnavi
# Enter age20
# my name is  vaishnavi my age is 20

# %%
a=input("Enter name")
print("Hello",a)
# Out:
# Enter name Vaishnavi
# Hello  Vaishnavi
