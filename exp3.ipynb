# %%
str1="10"
print(type(str1))
# Out:
# <class 'str'>

# %%
str1='dkte'
str2='college'
print(str1 + str2)
# Out:
# dktecollege

# %%
str1='dkte'
str2='college'
print(str1+' '+str2)
# Out:
# dkte college

# %%
str1="vaishnavi"
print(len(str1))
# Out:
# 9

# %%
str1="punde"
print(len(str1))
# Out:
# 5

# %%
str1="vaishnavi"
print(str1[1])
print(str1[0])
print(str1[8])
print(str1[6])
# Out:
# a
# v
# i
# a

# %%
str1="vaishnavi"
print(str1[11])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-e537266961b4> in <module>
#       1 str1="vaishnavi"
# ----> 2 print(str1[11])
#
# IndexError: string index out of range

# %%
str1='dkte college'
print(str1[1:3])
# Out:
# kt

# %%
str1='dkte college'
print(str1[0:3])
# Out:
# dkt

# %%
str1='dkte college'
print(str1[ :2])
# Out:
# dk

# %%
str1='dkte college'
print(str1[1: ])
# Out:
# kte college

# %%
str1='dkte college'
print(str1[ : ])
# Out:
# dkte college

# %%
str1='dkte college'
print(str1[1:6])
# Out:
# kte c

# %%
str1='dkte college'
print(str1[3:9])
# Out:
# e coll

# %%
str1='dkte'
print(str1[-1:-4])

# %%
str1="vaishnavi"
print(str1[3:4:7])
# Out:
# s

# %%
str1="vaishnavi"
print(str1[3:4])
# Out:
# s

# %%
str1="vaishnavi Ashok Punde"
print(str1[10:16])
# Out:
# Ashok

# %%
str1='Dkte'
print(str1.startswith('d'))
# Out:
# False

# %%
str1='Dkte'
print(str1.endswith('e'))
# Out:
# True

# %%
str1='Dkte'
print(str1.istitle())
print(str1.isupper())
print(str1.islower())
# Out:
# True
# False
# False

# %%
str1='Dkte'
print(str1.isalpha())
# Out:
# True

# %%
str1="Ichalkaranji"
print(str1.find('a'))
# Out:
# 3

# %%
str1="Ichalkaranji"
print(str1.count('a'))
# Out:
# 3

# %%
str1="Ichalkaranji"
print(str1.replace('a','k'))
# Out:
# Ichklkkrknji

# %%
str1="Ichalkaranji"
print(str1.replace('a','j'))
# Out:
# Ichjlkjrjnji

# %%
str1="1029"
print(str1.isdecimal())
# Out:
# True
